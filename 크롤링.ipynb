# %% [markdown]
# # 🗺️ Google Maps 리뷰 크롤러 v3.0
# **빈스얼랏 4,000건 리뷰 수집기** — Antigravity
#
# ## 사전 준비
#
# 2. Chrome에서 빈스얼랏 구글 맵 **리뷰 탭**을 열어두세요.
# 3. 아래 셀을 순서대로 실행하세요.

# %%
# ── 의존성 설치 (최초 1회)
# !pip install selenium webdriver-manager pandas openpyxl

import subprocess, sys
subprocess.run([sys.executable, "-m", "pip", "install", "-q",
    "selenium", "webdriver-manager", "pandas", "openpyxl"])

# %%
# gmaps_review_crawler.py 위치를 경로에 추가
import sys, os
sys.path.insert(0, os.path.dirname(os.path.abspath("__file__")))

# 크롤러 실행
from gmaps_review_crawler import connect_to_existing_chrome, crawl, save_results

driver   = connect_to_existing_chrome(9222)
reviews  = crawl(driver)
save_results(reviews)

print(f"
✅ 완료! 총 {len(reviews):,}건 수집")

# %%
# 결과 미리보기
import pandas as pd
df = pd.read_csv("빈스얼랏_리뷰.csv")
print(f"총 {len(df)}건 | 컬럼: {list(df.columns)}")
df.head()
